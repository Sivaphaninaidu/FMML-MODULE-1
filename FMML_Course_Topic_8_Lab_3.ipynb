# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivaphaninaidu/FMML-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 08:52:47--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.7MB/s    in 0.8s
#
# 2024-03-29 08:52:48 (90.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8175    1408.3967v4  In this study, we show that landmark detection...    cs
# 6716   1705.08056v1  Construction of ambiguity set in robust optimi...  stat
# 23684   1001.3735v1  Segmentation of medical images using seeded re...    cs
# 22768  1706.02492v1  We consider stationary autoregressive processe...  stat
# 40090  1710.06929v1  In this paper we introduce a system for unsupe...    cs
# ...             ...                                                ...   ...
# 16110  1609.08075v1  Non-linear models recently receive a lot of at...    cs
# 11129   1409.6981v1  Regression mixture models are widely studied i...  stat
# 4440   1710.10348v2  Deep residual networks (ResNets) and their var...  stat
# 22281  1511.07294v1  We consider convex-concave saddle point proble...  stat
# 19511  cs/0610015v1  In this paper we describe an architecture of a...    cs
#
#                                                    title  year  \
# 8175   Learning Deep Representation for Face Alignmen...  2014
# 6716   Ambiguity set and learning via Bregman and Was...  2017
# 23684  Gradient Based Seeded Region Grow method for C...  2010
# 22768  Consistency Results for Stationary Autoregress...  2017
# 40090  Unsupervised Object Discovery and Segmentation...  2017
# ...                                                  ...   ...
# 16110  S-MART: Novel Tree-based Structured Learning A...  2016
# 11129  Unsupervised learning of regression mixture mo...  2014
# 4440   Multi-level Residual Networks from Dynamical S...  2017
# 22281  Stochastic Parallel Block Coordinate Descent f...  2015
# 19511  Why did the accident happen? A norm-based reas...  2006
#
#                                                 keywords
# 8175   [detection, alignment, independent, robustness...
# 6716   [construction, ambiguity, optimization, diverg...
# 23684  [segmentation, technique, increasingly, knowle...
# 22768  [stationary, autoregressive, processes, coeffi...
# 40090  [introduce, unsupervised, discovery, segmentat...
# ...                                                  ...
# 16110  [attention, statistical, embedding, structured...
# 11129  [regression, statistics, regression, challengi...
# 4440   [applications, processing, theoretical, princi...
# 22281  [separable, structure, functions, efficient, s...
# 19511  [architecture, description, different, archite...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8175     [detection, alignment, independent, robustness...
# 6716     [construction, ambiguity, optimization, diverg...
# 23684    [segmentation, technique, increasingly, knowle...
# 22768    [stationary, autoregressive, processes, coeffi...
# 40090    [introduce, unsupervised, discovery, segmentat...
#                                ...
# 31250    [colonoscopy, contaminated, unsaturated, refle...
# 37944    [penalized, regression, attractive, framework,...
# 40       [artificial, classification, incorporate, sent...
# 26039    [influence, connections, convolutional, biomed...
# 39532    [algorithm, refinement, structure, parameters,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8803 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c8d0e8e-4362-4410-9e82-5f4144e02e69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c8d0e8e-4362-4410-9e82-5f4144e02e69")) {                    Plotly.newPlot(                        "4c8d0e8e-4362-4410-9e82-5f4144e02e69",                        [{"x":["correlation","outperforms","convergence","facilitate","drastically","alignment","optimization","complexity","specifically","attributes","independent","constrained","representation","correlated","different","especially","auxiliary","appearance","recognition","extensive","evaluations","information","occlusion","robustness","inference","expression","coefficients","detection","variation","difficulties","formulate","attribute","heterogeneous","concentration","functions","probability","generalization","asymptotic","statistical","construction","designing","approximating","divergences","asymmetric","wasserstein","objective","distribution","performance","divergence","classical","appropriate","ambiguity","distributions","unsupervised","anatomical","visualization","technique","angiography","intensity","applications","homogeneity","challenging","structures","increasingly","retrieval","selection","methodology","segmentation","knowledge","segmenting","databases","estimators","absolutely","stationary","simulations","penalized","estimation","including","processes","constraint","ellipsoid","autoregressive","consistency","universal","application","restricted","introduced","introduce","significantly","filtering","improving","scenarios","discovery","previously","positives","probabilistic","formulation","measurement","outperform","integrative","effectively","consistent","dirichlet","alternating","informative","transcriptome","transcripts","interactions","quantification","expressions","neighboring","simulation","integrate","collectively","interaction","likelihood","accurately","abundance","positively","promising","correlate","quantifications","transcript","sequencing","abundances","classification","alignments","sufficient","proportions","throughput","observation","experimental","experiments","estimated","efficient","therefore","responsible","throughout","essential","automatically","association","significant","indispensable","education","situation","undergraduate","statistics","descriptive","assessment","discriminant","associations","correlations","prediction","prototype","proactive","intelligent","contribution","interesting","university","recognize","recommendations","recommendation","leveraging","recommender","relaxation","recognized","controllable","attention","minimization","increasing","demonstrate","approximation","importance","substantially","relaxations","empirical","nonconvex","averaging","algorithm","comparable","framework","structure","intractable","benchmark","partition","regulatory","comparison","algorithms","precision","applicable","biological","currently","variables","following","meaningful","exponential","reconstruction","motivation","community","evaluated"],"y":[68,265,118,44,10,49,293,209,160,62,132,65,352,37,728,126,22,73,390,177,68,722,28,105,214,44,41,357,68,29,46,32,32,7,204,163,101,25,151,64,40,24,4,11,10,179,200,867,24,91,70,15,112,154,12,32,240,4,31,408,3,253,143,53,116,164,71,204,327,18,47,15,2,25,37,1,184,241,85,97,0,9,67,43,245,53,140,339,250,49,103,82,64,96,10,153,81,36,94,3,119,88,19,32,31,2,9,59,9,31,16,80,34,7,74,55,67,7,8,104,6,1,7,5,2,515,11,63,2,8,60,362,634,48,401,134,12,25,65,169,34,251,4,8,24,1,60,13,46,25,16,35,236,21,4,54,62,89,20,41,17,22,37,16,12,20,10,195,61,92,599,124,89,41,4,153,8,18,794,96,575,363,21,223,19,5,147,574,75,56,38,47,133,66,62,37,100,21,77,170],"type":"bar"},{"x":["correlation","outperforms","convergence","facilitate","drastically", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>Resolving</span> <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Ambiguity</span> <span style=''>Via</span> <span style=''>XSlit</span> <span style=''>Aspect</span> <span style=''>Ratio</span> <span style=''>Analysis</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>cameras</span> <span style=''>images</span> <span style=''>of</span> <span style=''>a</span> <span style=''>frontal</span> <span style=''>parallel</span> <span style=''>3D</span> <span style=''>object</span> <span style=''>preserve</span> <span style=''>its</span> <span style=''>aspect</span> <span style=''>ratio</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>its</span> <span style=''>depth</span> <span style=''>Such</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.35294117647058815);'>invariance</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>photography</span> <span style=''>but</span> <span style=''>is</span> <span style=''>unique</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>cameras</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>crossed</span> <span style=''>slit</span> <span style=''>or</span> <span style=''>XSlit</span> <span style=''>cameras</span> <span style=''>exhibit</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32123411978221406);'>different</span> <span style=''>depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>aspect</span> <span style=''>ratio</span> <span style=''>(DDAR)</span> <span style=''>property</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>3D</span> <span style=''>recovery</span> <span style=''>We</span> <span style=''>first</span> <span style=''>conduct</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.41463414634146345);'>comprehensive</span> <span style=''>analysis</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>DDAR</span> <span style=''>infer</span> <span style=''>object</span> <span style=''>depth</span> <span style=''>from</span> <span style=''>its</span> <span style=''>AR</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>recoverable</span> <span style=''>depth</span> <span style=''>range</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>and</span> <span style=''>error</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>repeated</span> <span style=''>shape</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Manhattan</span> <span style=''>World</span> <span style=''>scenes</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>3D</span> <span style='background-color:rgba(0, 255, 0, 0.3793103448275863);'>reconstruction</span> <span style=''>using ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Leverage</span> <span style=''>Score</span> <span style=''>Sampling</span> <span style=''>for</span> <span style=''>Faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Accelerated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>ERM</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>mathbfAinmathbbRntimes</span> <span style=''>d</span> <span style=''>and</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>b</span> <span style=''>inmathbbRd</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>an</span> <span style=''>epsilon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problem</span> <span style=''>min</span> <span style=''>xinmathbbRdfrac12</span> <span style=''>|mathbfA</span> <span style=''>x</span> <span style=''>b|</span> <span style=''>22</span> <span style=''>in</span> <span style=''>time</span> <span style=''>tildeO</span> <span style=''>((nsqrtdcdotkappa</span> <span style=''>textsum)cdot</span> <span style=''>scdotlogepsilon</span> <span style=''>1)</span> <span style=''>where</span> <span style=''>kappa</span> <span style=''>textsummathrmtrleft(mathbfAtopmathbfAright)lambda</span> <span style=''>min(mathbfATmathbfA)</span> <span style=''>and</span> <span style=''>s</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>number</span> <span style=''>of</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>entries</span> <span style=''>in</span> <span style=''>a</span> <span style=''>row</span> <span style=''>of</span> <span style=''>mathbfA</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>best</span> <span style=''>running</span> <span style=''>time</span> <span style=''>of</span> <span style=''>tildeO</span> <span style=''>((nsqrtn</span> <span style=''>cdotkappa</span> <span style=''>textsum)cdot</span> <span style=''>scdotlogepsilon</span> <span style=''>1)</span> <span style=''>We</span> <span style=''>achieve</span> <span style=''>our</span> <span style=''>result</span> <span style=''>through</span> <span style=''>a</span> <span style=''>careful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>leverage</span> <span style=''>score</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>proximal</span> <span style=''>point</span> <span style=''>methods</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>not</span> <span style=''>only</span> <span style=''>matches</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>previous</span> <span style=''>methods</span> <span style=''>but</span> <span style=''>further</span> <span style=''>improves</span> <span style=''>whenever</span> <span style=''>leverage</span> <span style=''>scores</span> <span style=''>of</span> <span style=''>rows</span> <span style=''>are</span> <span style=''>small</span> <span style=''>(up</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>po ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4400000000000001);'>Predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approaches</span> <span style=''>For</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>(GPC)</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.32123411978221406);'>different</span> <span style=''>Leave</span> <span style=''>One</span> <span style=''>Out</span> <span style=''>(LOO)</span> <span style=''>Cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Validation</span> <span style=''>(CV)</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>criteria</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>LOO</span> <span style='background-color:rgba(255, 0, 0, 0.4400000000000001);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3507246376811596);'>distributions</span> <span style=''>with</span> <span style=''>such</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>select</span> <span style='background-color:rgba(255, 0, 0, 0.30000000000000004);'>hyperparameters</span> <span style=''>Apart</span> <span style=''>from</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>average</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>logarithm</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4400000000000001);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>(NLP)</span> <span style=''>we</span> <span style=''>also</span> <span style=''>consider</span> <span style=''>smoothed</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>criteria</span> <span style=''>such</span> <span style=''>as</span> <span style=''>F</span> <span style=''>measure</span> <span style=''>and</span> <span style=''>Weighted</span> <span style=''>Error</span> <span style=''>Rate</span> <span style=''>(WER)</span> <span style=''>which</span> <span style=''>are</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>handling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>data</span> <span style=''>Unlike</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5257731958762888);'>regression</span> <span style=''>case</span> <span style=''>LOO</span> <span style='background-color:rgba(255, 0, 0, 0.4400000000000001);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3507246376811596);'>distributions</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>case</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style=''>We</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>LOO</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Combating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Attacks</span> <span style=''>Using</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>by</span> <span style=''>now</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>small</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbations</span> <span style=''>can</span> <span style=''>induce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>errors</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNNs)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>make</span> <span style=''>the</span> <span style=''>case</span> <span style=''>that</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>are</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combating</span> <span style=''>such</span> <span style=''>attacks</span> <span style=''>For</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsifying</span> <span style=''>front</span> <span style=''>end</span> <span style=''>is</span> <span style=''>provably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>against</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>bounded</span> <span style=''>attacks</span> <span style=''>reducing</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distortion</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>attack</span> <span style=''>by</span> <span style=''>a</span> <span style=''>factor</span> <span style=''>of</span> <span style=''>roughly</span> <span style=''>K</span> <span style=''>N</span> <span style=''>where</span> <span style=''>N</span> <span style=''>is</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style=''>K</span> <span style=''>is</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>level</span> <span style=''>We</span> <span style=''>then</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>concept</span> <span style=''>to</span> <span style=''>DNNs</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>a</span> <span style=''>locally</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundation</span> <span style=''>for</span> <span style=''>crafting</span> <span style=''>attacks</span> <span style=''>and</span> <span style=''>defenses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>for</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1287339971550498)
# 	knowledge (0.1162873399715505)
# 	representation (0.1251778093883357)
# 	architecture (0.08854907539118065)
# 	segmentation (0.07254623044096728)
# 	detection (0.12695590327169273)
# 	different (0.25889046941678523)
# 	information (0.25675675675675674)
# 	convolutional (0.1337126600284495)
# 	recognition (0.1386913229018492)
#
# Some Statistics words are:
# 	variables (0.13732394366197184)
# 	algorithm (0.37927565392354123)
# 	statistical (0.1574446680080483)
# 	estimation (0.170523138832998)
# 	stochastic (0.14587525150905434)
# 	theoretical (0.16046277665995975)
# 	distribution (0.19014084507042253)
# 	dimensional (0.18963782696177062)
# 	inference (0.2022132796780684)
# 	regression (0.18611670020120724)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7756396-5252-4f89-b922-0efde97356f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7756396-5252-4f89-b922-0efde97356f8")) {                    Plotly.newPlot(                        "b7756396-5252-4f89-b922-0efde97356f8",                        [{"x":["correlation","outperforms","convergence","facilitate","drastically","alignment","optimization","complexity","specifically","attributes","independent","constrained","representation","correlated","different","especially","auxiliary","appearance","recognition","extensive","evaluations","information","occlusion","robustness","inference","expression","coefficients","detection","variation","difficulties","formulate","attribute","heterogeneous","concentration","functions","probability","generalization","asymptotic","statistical","construction","designing","approximating","divergences","asymmetric","wasserstein","objective","distribution","performance","divergence","classical","appropriate","ambiguity","distributions","unsupervised","anatomical","visualization","technique","angiography","intensity","applications","homogeneity","challenging","structures","increasingly","retrieval","selection","methodology","segmentation","knowledge","segmenting","databases","estimators","absolutely","stationary","simulations","penalized","estimation","including","processes","constraint","ellipsoid","autoregressive","consistency","universal","application","restricted","introduced","introduce","significantly","filtering","improving","scenarios","discovery","previously","positives","probabilistic","formulation","measurement","outperform","integrative","effectively","consistent","dirichlet","alternating","informative","transcriptome","transcripts","interactions","quantification","expressions","neighboring","simulation","integrate","collectively","interaction","likelihood","accurately","abundance","positively","promising","correlate","quantifications","transcript","sequencing","abundances","classification","alignments","sufficient","proportions","throughput","observation","experimental","experiments","estimated","efficient","therefore","responsible","throughout","essential","automatically","association","significant","indispensable","education","situation","undergraduate","statistics","descriptive","assessment","discriminant","associations","correlations","prediction","prototype","proactive","intelligent","contribution","interesting","university","recognize","recommendations","recommendation","leveraging","recommender","relaxation","recognized","controllable","attention","minimization","increasing","demonstrate","approximation","importance","substantially","relaxations","empirical","nonconvex","averaging","algorithm","comparable","framework","structure","intractable","benchmark","partition","regulatory","comparison","algorithms","precision","applicable","biological","currently","variables","following","meaningful","exponential","reconstruction","motivation","community","evaluated","communities","principle","overlapping","byproduct","comprises","processing","programming","formalism","computing","propositional","cardinality","effective","collected","benchmarks","relatively","collision","techniques","combining","aircrafts","difficult","regression","backgrounds","avoidance","stabilization","potential","combination","dimension","sometimes","inability","requisite","potentially","reduction","predictive","simulated","predictors","subspaces","covariate","weighting","optimizing","dimensions","traintest","conditioned","projections","assumptions","independencies","graphical","invariances","particular","mathematical","compactly","complicated","extension","independence","represented","associated","projected","m ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ellipsoid
# 	infectious
# 	pretreatment
# 	assortment
# 	martingale
# 	penalization
# 	katehakis
# 	emphdirectly
# 	unsettled
# 	entrywise
# 	robustify
# 	submodularity
# 	supersparse
# 	quantiles
# 	tabulation
# 	marginalize
# 	beautiful
# 	positivity
# 	emphsparse
# 	blockmodels
# Some words which never appear in Statistics papers:
# 	angiography
# 	transcriptome
# 	transcripts
# 	transcript
# 	sequencing
# 	descriptive
# 	proactive
# 	propositional
# 	aircrafts
# 	backgrounds
# 	avoidance
# 	milliseconds
# 	maneuvers
# 	syntactic
# 	creativity
# 	detectable
# 	evolutions
# 	tensorial
# 	factories
# 	inevitable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0564215416590254e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7516666666666667
